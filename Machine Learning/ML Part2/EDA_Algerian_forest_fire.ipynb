# %% [markdown]
# # Algerian Forest fires EDA

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
data_path = r'C:\Users\Adeeb Khan\pwskillsassignment\Machine Learning\ML Part2\datasets\Algerian_forest_fires_dataset_UPDATE (6) (1).csv'

# %%
df = pd.read_csv(data_path, header=1)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
df.describe()
# Out:
#         day month  year Temperature   RH   Ws Rain   FFMC  DMC   DC  ISI  BUI  \
# count   246   245   245         245  245  245   245   245  245  245  245  245
# unique   33     5     2          20   63   19    40   174  167  199  107  175
# top      01    07  2012          35   64   14     0  88.9  7.9    8  1.1    3
# freq      8    62   244          29   10   43   133     8    5    5    8    5
#
#         FWI Classes
# count   245       244
# unique  128         9
# top     0.4   fire
# freq     12       131

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
# divide dataset

df.loc[:122, 'Region'] = 1
df.loc[122:, 'Region'] = 2
df[['Region']] = df[['Region']].astype(int)

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 123  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 123  FWI  Classes         2

# %%
df = df.drop(123, axis=0)

# %%
df.reset_index(drop = True, inplace=True)

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']] = df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']].astype('int')

# %%
def clean_and_convert(value):
    # Split the value by whitespace and take the first part
    cleaned_value = value.replace(" ", "")
    # Convert to float
    return cleaned_value

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2      3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4      5      6  2012           27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...  ...   ...  ...   ...
# 238   26      9  2012           30  65  14     0  85.4   16  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI       Classes  Region
# ...

# %%
objects = [features for features in df.columns if df[features].dtypes=='O']

for i in objects:
    if i != 'Classes':
        print(i)
        df[i] = df[i].apply(clean_and_convert)
        df[i] = df[i].astype(float)
# Out:
# Rain
# FFMC
# DMC
# DC
# ISI
# BUI
# FWI

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.shape
# Out:
# (243, 15)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [day, month, year, Temperature, RH, Ws, Rain, FFMC, DMC, DC, ISI, BUI, FWI, Classes, Region]
# Index: []

# %% [markdown]
# - No Duplicates

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 22.0+ KB

# %%
df.describe().T
# Out:
#              count         mean        std     min      25%     50%      75%  \
# day          243.0    15.761317   8.842552     1.0     8.00    16.0    23.00
# month        243.0     7.502058   1.114793     6.0     7.00     8.0     8.00
# year         243.0  2012.000000   0.000000  2012.0  2012.00  2012.0  2012.00
# Temperature  243.0    32.152263   3.628039    22.0    30.00    32.0    35.00
# RH           243.0    62.041152  14.828160    21.0    52.50    63.0    73.50
# Ws           243.0    15.493827   2.811385     6.0    14.00    15.0    17.00
# Rain         243.0     0.762963   2.003207     0.0     0.00     0.0     0.50
# FFMC         243.0    77.842387  14.349641    28.6    71.85    83.3    88.30
# DMC          243.0    14.680658  12.393040     0.7     5.80    11.3    20.80
# DC           243.0    49.430864  47.665606     6.9    12.35    33.1    69.10
# ISI          243.0     4.742387   4.154234     0.0     1.40     3.5     7.25
# ...

# %%
df.Classes.value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
# Bejaia Region
# Region 1
df[:122]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1      2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2      3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3      4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4      5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...  ...   ...  ...  ...
# 117   26      9  2012           31  54  11   0.0  82.0  6.0  16.3  2.5  6.2
# 118   27      9  2012           31  66  11   0.0  85.7  8.3  24.9  4.0  9.0
# 119   28      9  2012           32  47  14   0.7  77.5  7.1   8.8  1.8  6.8
# 120   29      9  2012           26  80  16   1.8  47.4  2.9   7.7  0.3  3.0
# 121   30      9  2012           25  78  14   1.4  45.0  1.9   7.5  0.2  2.4
#
#      FWI      Classes  Region
# ...

# %%
# Sidi-Bel Abbes Region
# Region 2
df[122:]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 122    1      6  2012           32  71  12   0.7  57.1   2.5   8.2  0.6   2.8
# 123    2      6  2012           30  73  13   4.0  55.7   2.7   7.8  0.6   2.9
# 124    3      6  2012           29  80  14   2.0  48.7   2.2   7.6  0.3   2.6
# 125    4      6  2012           30  64  14   0.0  79.4   5.2  15.4  2.2   5.6
# 126    5      6  2012           32  60  14   0.2  77.1   6.0  17.6  1.8   6.5
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI       Classes  Region
# ...

# %%
df1 = df.drop(['day', 'month', 'year'], axis=1)

# %%
df1['Classes'] = np.where(df1['Classes'] == 'not fire', 0, 1)

# %%
df1
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5        1
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4        1
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1        1
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0        1
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5        1
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...      ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        1
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        1
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        1
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        1
#
#      Region
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
sns.heatmap(df1.corr())
# Out:
# <Axes: >

# %%
df1.hist()
# Out:
# array([[<Axes: title={'center': 'Temperature'}>,
#         <Axes: title={'center': 'RH'}>, <Axes: title={'center': 'Ws'}>],
#        [<Axes: title={'center': 'Rain'}>,
#         <Axes: title={'center': 'FFMC'}>,
#         <Axes: title={'center': 'DMC'}>],
#        [<Axes: title={'center': 'DC'}>, <Axes: title={'center': 'ISI'}>,
#         <Axes: title={'center': 'BUI'}>],
#        [<Axes: title={'center': 'FWI'}>,
#         <Axes: title={'center': 'Classes'}>,
#         <Axes: title={'center': 'Region'}>]], dtype=object)

# %%
plt.style.use('seaborn')
df1.hist(bins=50, figsize=(20,15), ec='b')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Adeeb Khan\pwskillsassignment\.conda\Lib\site-packages\matplotlib\style\core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File c:\Users\Adeeb Khan\pwskillsassignment\.conda\Lib\site-packages\matplotlib\__init__.py:879, in _rc_params_in_file(fname, transform, fail_on_error)
#     878 rc_temp = {}
# --> 879 with _open_file_or_url(fname) as fd:
#     880     try:
#
# File c:\Users\Adeeb Khan\pwskillsassignment\.conda\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File c:\Users\Adeeb Khan\pwskillsassignment\.conda\Lib\site-packages\matplotlib\__init__.py:856, in _open_file_or_url(fname)
#     855 fname = os.path.expanduser(fname)
# ...

# %%
# Percentage for PieChart
df.Classes = df.Classes.str.strip()
percentage = df.Classes.value_counts(normalize=True)*100
percentage
# Out:
# Classes
# fire        56.378601
# not fire    43.621399
# Name: proportion, dtype: float64

# %%
#plotting PieChart
classeslabels = ["FIRE", "NOT FIRE"]
plt.figure(figsize =(12, 7))
plt.pie(percentage,labels = classeslabels,autopct='%1.1f%%')
plt.title ("Pie Chart of Classes", fontsize = 15)
plt.show()
